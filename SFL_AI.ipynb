# %%
#pip install NeuralProphet

# %%
#pip install plotly

# %%
#from neuralprophet import NeuralProphet

# %%
import pandas as pd

# %%
ls drive/MyDrive/Colab\ Notebooks
# Out:
#  BOS_November06_2022.csv            PythonCourse24/
# 'Copy of Welcome To Colaboratory'   setForLife.csv
#  Finances22.ipynb                   set-for-life-draw-history-4Mar24.csv
# 'finances Nov 22.gsheet'            SetForLife.ipynb
#  NewburyFloodDataFlowOnly.csv       SFL_AI.ipynb
#  NewburyFloodData.ipynb

# %%
sfl_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/setForLife.csv")

# %%
#sfl_df["DrawDate"] = pd.to_datetime(sfl_df["DrawDate"])

# %%
sfl_df.head()
# Out:
#       DrawDate  Ball 1  Ball 2  Ball 3  Ball 4  Ball 5  Life Ball Ball Set  \
# 0  18-Apr-2024      18      35       6      26      41          5     SFL9
# 1  15-Apr-2024       1      21      27       3      22         10     SFL8
# 2  11-Apr-2024      11      13      19      42      27          8     SFL9
# 3  08-Apr-2024      36      43       3       5       6          1     SFL8
# 4  04-Apr-2024      17      41       2      16       9          3     SFL7
#
#        Machine  DrawNumber
# 0  Excalibur 5         532
# 1  Excalibur 5         531
# 2  Excalibur 4         530
# 3  Excalibur 4         529
# 4  Excalibur 4         528

# %%
sfl_df = sfl_df.drop(columns = ["Ball Set", "Machine", "DrawNumber"])

# %%
sfl_df["DrawDate"] = pd.to_datetime(sfl_df["DrawDate"])
sfl_df.set_index('DrawDate',inplace=True)
sfl_df.head()
# Out:
#             Ball 1  Ball 2  Ball 3  Ball 4  Ball 5  Life Ball
# DrawDate
# 2024-04-18      18      35       6      26      41          5
# 2024-04-15       1      21      27       3      22         10
# 2024-04-11      11      13      19      42      27          8
# 2024-04-08      36      43       3       5       6          1
# 2024-04-04      17      41       2      16       9          3

# %%
#should i separate this into two models, main and life ball? Hmm. Together for now.

# %%
#model = NeuralProphet()
#model.fit(sfl)
#this is completely the wrong type of model.

# %%
#Try a K-Means unsupervised learning model??? No that's a cluster model.
#TensorFlow? that's some complicated stuff for a newbie.
#so I want a simple linear regression model, not unsupervised, it's not looking for clusters.

# %%
#sklearn has got to be the most simple!
