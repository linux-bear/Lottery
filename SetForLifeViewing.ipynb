# %%
# %store -r numbers

# %%
listyList = []
for row in numbers:
    tempList = []
    for num in row:
        pynum = num.item()
        tempList.append(pynum)
    listyList.append(tempList)

# %%
listyList
# Out:
# [[18, 19, 22, 34, 40],
#  [18, 38, 42, 45, 46],
#  [2, 30, 39, 41, 45],
#  [17, 18, 23, 33, 44],
#  [6, 14, 22, 28, 36],
#  [18, 21, 24, 29, 47],
#  [6, 18, 21, 25, 34],
#  [5, 32, 34, 38, 44],
#  [3, 6, 7, 14, 18],
#  [2, 4, 8, 11, 28],
#  [8, 9, 21, 32, 42],
#  [3, 6, 24, 27, 34],
#  [3, 11, 17, 18, 23],
#  [11, 26, 28, 32, 39],
#  [4, 11, 26, 44, 47],
#  [2, 4, 7, 22, 34],
#  [4, 6, 9, 10, 40],
#  [3, 5, 13, 31, 39],
#  [11, 17, 26, 29, 47],
#  [3, 9, 17, 23, 41],
#  [15, 17, 27, 35, 39],
#  [3, 4, 22, 30, 34],
#  [5, 8, 14, 18, 20],
#  [3, 8, 14, 17, 25],
#  [2, 4, 34, 37, 46],
#  [7, 12, 19, 21, 31],
#  [8, 10, 12, 28, 45],
#  [1, 15, 34, 35, 38],
#  [13, 17, 37, 44, 45],
#  [7, 31, 36, 39, 44],
#  [1, 12, 14, 19, 42],
#  [23, 36, 41, 42, 46],
#  [11, 21, 22, 27, 41],
#  [7, 13, 27, 33, 40],
#  [6, 9, 15, 19, 34],
#  [14, 18, 23, 28, 46],
#  [3, 27, 42, 45, 46],
#  [12, 14, 19, 23, 32],
#  [6, 7, 31, 38, 42],
#  [20, 21, 24, 27, 36],
#  [8, 20, 25, 35, 40],
# ...
