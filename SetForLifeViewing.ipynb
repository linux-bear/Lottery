# %%
# %store -r numbers

# %%
numbers
# Out:
# [[20, 32, 33, 43, 45],
#  [10, 18, 24, 27, 38],
#  [6, 22, 23, 36, 41],
#  [10, 16, 19, 24, 38],
#  [28, 30, 31, 32, 42],
#  [3, 24, 29, 31, 41],
#  [2, 11, 15, 19, 38],
#  [5, 11, 12, 25, 26],
#  [4, 7, 13, 28, 34],
#  [14, 20, 31, 40, 43],
#  [9, 10, 25, 32, 41],
#  [4, 12, 16, 21, 26],
#  [5, 10, 19, 23, 44],
#  [1, 14, 17, 27, 35],
#  [11, 15, 26, 33, 44],
#  [5, 10, 14, 35, 45],
#  [6, 18, 22, 29, 40],
#  [3, 27, 43, 46, 47],
#  [1, 17, 26, 39, 46],
#  [6, 18, 26, 35, 41],
#  [1, 3, 21, 22, 27],
#  [11, 13, 19, 27, 42],
#  [3, 5, 6, 36, 43],
#  [2, 9, 16, 17, 41],
#  [19, 30, 35, 40, 44],
#  [5, 10, 19, 26, 41],
#  [11, 23, 24, 26, 35],
#  [3, 4, 11, 14, 18],
#  [2, 11, 19, 38, 43],
#  [4, 11, 22, 25, 34],
#  [12, 21, 30, 35, 44],
#  [11, 29, 32, 34, 42],
#  [7, 15, 25, 30, 38],
#  [4, 6, 28, 29, 45],
#  [3, 10, 21, 24, 39],
#  [16, 17, 19, 23, 38],
#  [7, 11, 12, 36, 46],
#  [5, 11, 25, 30, 42],
#  [6, 20, 27, 29, 36],
#  [13, 19, 26, 37, 43],
#  [3, 4, 8, 10, 28],
# ...
