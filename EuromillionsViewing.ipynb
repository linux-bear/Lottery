# %%
# %store -r numbersEuro

# %%
numbersEuro
# Out:
# [[2, 13, 16, 24, 32],
#  [7, 15, 34, 45, 48],
#  [15, 16, 26, 30, 37],
#  [6, 7, 9, 14, 43],
#  [4, 7, 16, 33, 34],
#  [16, 18, 35, 36, 41],
#  [9, 12, 18, 22, 50],
#  [11, 13, 14, 34, 48],
#  [18, 31, 32, 41, 46],
#  [2, 8, 17, 28, 35],
#  [13, 28, 29, 44, 48],
#  [35, 36, 41, 42, 45],
#  [6, 9, 10, 30, 49],
#  [13, 22, 24, 33, 47],
#  [2, 20, 39, 40, 47],
#  [6, 9, 11, 32, 49],
#  [10, 20, 40, 44, 46],
#  [22, 29, 31, 39, 46],
#  [2, 3, 12, 16, 45],
#  [19, 23, 26, 27, 46],
#  [13, 18, 26, 35, 37],
#  [1, 23, 31, 36, 48],
#  [16, 17, 35, 36, 49],
#  [2, 13, 14, 26, 29],
#  [8, 11, 23, 32, 44],
#  [7, 16, 18, 20, 32],
#  [1, 4, 31, 34, 40],
#  [13, 19, 30, 38, 46],
#  [8, 11, 12, 16, 44],
#  [2, 15, 17, 23, 36],
#  [4, 7, 19, 20, 34],
#  [3, 4, 9, 12, 20],
#  [24, 27, 28, 30, 49],
#  [23, 31, 37, 42, 48],
#  [8, 13, 14, 24, 26],
#  [13, 17, 18, 20, 46],
#  [23, 24, 35, 37, 45],
#  [2, 7, 21, 28, 45],
#  [13, 20, 23, 27, 42],
#  [5, 10, 19, 27, 30],
#  [8, 19, 32, 41, 42],
# ...
